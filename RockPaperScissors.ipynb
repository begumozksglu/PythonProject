# %% [markdown]
# ### TAŞ, KAĞIT MAKAS OYUNU

# %%
import random 

player_score , computer_score = 0,0
computer_choice = 1
def print_result(winner = "Bilgisayar"):
    global computer_score, player_score
    print(f"Bilgisarın seçimi: {computer_choice}\n Kazanan: {winner}")
    if winner == "Bilgisayar":
        computer_score += 100
    else:
        player_score += 100


print("Taş Kağıt Makas Oyunumuza Hoş Geldiniz' \n" +("-"*39))

while True:
    print("\n 1 -> Taş\n 2 -> Kağıt\n 3 -> Makas \n Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.")
    player_choice = int(input("Seçiminizi yapınız: "))
    computer_choice = random.choice([1, 2, 3])
   
    if player_choice == computer_choice:
        print("Berabere, yeniden oynayınız.")
    elif player_choice == 1:
        if computer_choice == 2:
            print_result()       
        else:
            print_result("Kullanıcı")          
    elif player_choice == 2:
        if computer_choice == 1:
           print_result("Kullanıcı")
        else:
           print_result()
    elif player_choice == 3:
        if computer_choice == 1:
          print_result()
        else:
          print_result("Kullanıcı")
    else:
        break
    
print(f"\nKullanıcı skoru: {player_score}\nBilgisayarın skoru: {computer_score}")
if player_score < computer_score:
    print(f"Kullanıcı {computer_score - player_score} farkla bilgisayara yenilmiştir.")
elif player_score >computer_score:
    print(f"Bilgisayar {player_score - computer_score} farkla kullanıcıya yenilmiştir")
else:
    print("Oyun berabere!")
# Out:
# Taş Kağıt Makas Oyunumuza Hoş Geldiniz'
# ---------------------------------------
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 1
# Berabere, yeniden oynayınız.
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 2
# Bilgisarın seçimi: 1
#  Kazanan: Kullanıcı
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 3
# Berabere, yeniden oynayınız.
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 4
#
# Kullanıcı skoru: 100
# Bilgisayarın skoru: 0
# Bilgisayar 100 farkla kullanıcıya yenilmiştir

# %%
import random 

player_score , computer_score = 0,0
computer_choice = 1
def print_result(winner = "Bilgisayar"):
    global computer_score, player_score
    print(f"Bilgisarın seçimi: {computer_choice}\n Kazanan: {winner}")
    if winner == "Bilgisayar":
        computer_score += 100
    else:
        player_score += 100


print("Taş Kağıt Makas Oyunumuza Hoş Geldiniz' \n" +("-"*39))

while True:
    print("\n 1 -> Taş\n 2 -> Kağıt\n 3 -> Makas \n Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.")
    player_choice = int(input("Seçiminizi yapınız: "))
    computer_choice = random.choice([1, 2, 3])
   
    if player_choice == computer_choice:
        print("Berabere, yeniden oynayınız.")
    elif player_choice == 1:
        if computer_choice == 2:
            print_result()       
        else:
            print_result("Kullanıcı")          
    elif player_choice == 2:
        if computer_choice == 1:
           print_result("Kullanıcı")
        else:
           print_result()
    elif player_choice == 3:
        if computer_choice == 1:
          print_result()
        else:
          print_result("Kullanıcı")
    else:
        break
    
print(f"\nKullanıcı skoru: {player_score}\nBilgisayarın skoru: {computer_score}")
if player_score < computer_score:
    print(f"Kullanıcı {computer_score - player_score} farkla bilgisayara yenilmiştir.")
elif player_score >computer_score:
    print(f"Bilgisayar {player_score - computer_score} farkla kullanıcıya yenilmiştir")
else:
    print("Oyun berabere!")
# Out:
# Taş Kağıt Makas Oyunumuza Hoş Geldiniz'
# ---------------------------------------
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 1
# Berabere, yeniden oynayınız.
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 2
# Bilgisarın seçimi: 1
#  Kazanan: Kullanıcı
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 3
# Bilgisarın seçimi: 2
#  Kazanan: Kullanıcı
#
#  1 -> Taş
#  2 -> Kağıt
#  3 -> Makas
#  Oyundan çıkmak isterseniz bu değerler dışında bir değer giriniz.
# Seçiminizi yapınız: 5
#
# Kullanıcı skoru: 200
# Bilgisayarın skoru: 0
# Bilgisayar 200 farkla kullanıcıya yenilmiştir
